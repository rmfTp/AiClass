# %%
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\김용준\08 데이터 분석을 위한 python\source\basic\lib\site-packages (4.13.4)
# Requirement already satisfied: soupsieve>1.2 in c:\김용준\08 데이터 분석을 위한 python\source\basic\lib\site-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\김용준\08 데이터 분석을 위한 python\source\basic\lib\site-packages (from beautifulsoup4) (4.13.2)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
from bs4 import BeautifulSoup as bs
html = requests.get("https://news.naver.com").text
soup = bs(html, 'html.parser')
body = soup.select_one('body')
text = body.get_text().strip().replace('\n',' ')
stopwords = ['본문', '바로가기', 'NAVER']

text
# Out:
# '본문 바로가기        NAVER  뉴스   엔터     스포츠     날씨     프리미엄     대선           검색             언론사별 정치 경제 사회 생활/문화 IT/과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 알고리즘 안내 정정보도 모음              콘텐츠   6.4(수)   전체 언론사 뉴스스탠드 라이브러리           언론사편집  기자                                                 연재                                                                  구독설정                                       속보     이재명 대통령, 취임 후 첫 행정명령으로 ‘비상경제점검 TF 구성’ 지시    KBS  내용작성전      李대통령 공약 ‘대법관 증원법’ 법사소위 통과…14명→ 30명    국제신문  내용작성전      이주호, 이 대통령에게 전체 국무위원 사의 표명    경향신문       李대통령 공약 ‘대법관 증원법’ 법사위 소위 통과…16명 늘려 30명    매경이코노미  내용작성전      이주호 총리 대행, 李대통령에 전체 국무위원 사의 표명    kbc광주방송       이주호 부총리, 이재명 대통령에게 전체 국무위원 사의 표명    부산일보       이주호 부총리, 李대통령에게 전체 국무위원 사의 표명    채널A       이주호, 이재명 대통령에게 국무위원 전체 사의 표명    대전일보       李 공약 \'대법관 증원법\' 법사소위 통과…16명 늘려 30명    중앙일보       이 대통령 공약 \'대법관 증원법\' 법사소위 통과…16명 늘려 30명    SBS  내용작성전     속보 닫기             경기일보 06월 04일 16:43  구독      "첫눈에 반한 사람은 김혜경"… 소개팅서 만난 \'운명의 상대\', 평생의 지원군으로    이재명 정부 첫 인사… 국무총리 김민석·비서실장 강훈식·국정원장 이종석 지명   조국, 옥중서신서 "정권교체는 국민 승리"   이재명 대통령 “용산 무덤같아…컴퓨터·필기구도 없어”            디지털데일리 06월 04일 16:58  구독      [이재명 당선] \'균형발전\' 기조에 쏠린 눈…소부장 생태계, 재편 신호탄    [이재명 당선] 게임 국내 질병코드 등재 막을까…게임업계 기대감 고조   배터리 사용량 40% 올라도 점유율 하락한 K-배터리…CATL·BYD \'폭풍 성장\' [소부장박대리]   [스노우플레이크 서밋] 샘 올트먼이 말한 ‘모두가 쓰는 AI’ 조건은?            뉴스타파 06월 02일 20:45  구독      또다른 \'자손군\' 댓글팀 \'민주당해산운동본부 트루스코리아\'...100만원씩 포상금    [목소리 프로젝트 : 에너지] 기후위기 돌파구, 누가 진짜 그린 리더인가?   [KINN] ‘한덕수 대망론’, 언론개혁 절실함을 보여주다   리박스쿨 \'댓글부대 단장\'이 아이들 상대 \'역사 강의\'            비즈워치 06월 04일 15:34  구독
 ○○ 같아요"…폭소 터진 이재명 대통령의 첫 브리핑    "이재명 덕분에 돈 벌어" 개미 환호…지역화폐·지주사 신고가 터졌다   "한우가 반값" "수박 한통 9900원"…대선 끝나자 파격 할인   "이재명 당선 기념 8천원 백반이 공짜"…통 크게 쏜 광주 식당            헬스조선 06월 04일 16:23  구독      ‘6kg 감량’ 맹승지, 매일 하는 루틴… “일어나자마자 ‘이것’부터 마셔”    “‘이곳’ 털 엉키며 통증, 탈모까지” 충격… 마라톤 중이던 60대 男, 무슨 일?   "라미란, 살 또 빠졌네?"… 14kg 감량 비결은 \'이것\' 섭취 줄인 것   “다이어트 중, 6kg 감량” 이국주, ‘이 음식’으로 뺐다던데… 뭘까?            TV조선 06월 04일 16:49  구독      李 대통령, 초대 총리 김민석 지명…국정원장 후보자 이종석    李 "당장 가능한 경제회생책 점검…핵심은 추경"   이주호, 李 대통령에 \'전체 국무위원 사의\'…선별 수리하나   법원 "탈덕수용소 운영자, \'아이브 소속사\'에 5천만원 배상" 판결            주간경향 06월 04일 14:35  구독      이 대통령, 국무총리 김민석·국정원장 이종석 지명    이 대통령 “박정희 정책도, 김대중 정책도 필요하면 쓸 것”   국민의힘, 충격 속 침묵···“상당히 많은 차이 아쉽다”   권영국 “사표 될까 우려하면서도 기꺼이 모아준 한 표···이 마음 모아 다시 시작할 것”            매경이코노미 06월 04일 16:53  구독      [속보] 李대통령 공약 ‘대법관 증원법’ 법사위 소위 통과…16명 늘려 30명    [속보] 李 “용산 대통령실 무덤같아…컴퓨터·필기도구·프린터기 없어”   “김혜경에 첫눈에 반했다”…초짜 변호사의 결혼 성공 비결 ...

# %%
# !pip install konlpy

# %%
# !pip install Jpyp

# %%
from konlpy.tag import Okt

# %%
okt = Okt()
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 okt = Okt()
#
# File c:\김용준\08 데이터 분석을 위한 python\source\basic\Lib\site-packages\konlpy\tag\_okt.py:51, in Okt.__init__(self, jvmpath, max_heap_size)
#      49 def __init__(self, jvmpath=None, max_heap_size=1024):
#      50     if not jpype.isJVMStarted():
# ---> 51         jvm.init_jvm(jvmpath, max_heap_size)
#      53     oktJavaPackage = jpype.JPackage('kr.lucypark.okt')
#      54     OktInterfaceJavaClass = oktJavaPackage.OktInterface
#
# File c:\김용준\08 데이터 분석을 위한 python\source\basic\Lib\site-packages\konlpy\jvm.py:64, in init_jvm(jvmpath, max_heap_size)
#      61     jvmpath = '%s/lib/jli/libjli.dylib' % jvmpath.split('/lib/')[0]
#      63 if jvmpath:
# ---> 64     jpype.startJVM(jvmpath, '-Dfile.encoding=UTF8',
#      65                             '-ea', '-Xmx{}m'.format(max_heap_size),
#      66                             classpath=classpath,
#      67                             convertStrings=True)
#      68 else:
#      69     raise ValueError("Please specify the JVM path.")
#
# File c:\김용준\08 데이터 분석을 위한 python\source\basic\Lib\site-packages\jpype\_core.py:357, in startJVM(jvmpath, classpath, ignoreUnrecognized, convertStrings, interrupt, *jvmargs)
#     355 prior = [locale.getlocale(i) for i in categories]
#     356 # Start the JVM
# --> 357 _jpype.startup(jvmpath, tuple(jvm_args + extra_jvm_args),
#     358                ignoreUnrecognized, convertStrings, interrupt, tmp)
#     359 # Collect required resources for operation
#     360 initializeResources()
#
# SystemError: java.lang.UnsatisfiedLinkError: C:\: Can't find dependent libraries
